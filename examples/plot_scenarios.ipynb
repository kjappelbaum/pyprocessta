# %%
import pickle
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
with open('20210429-095404_TI-19_TI-1213_-20.0_20.0_21_amine', 'rb') as handle:
    res = pickle.load(handle)

# %%
res
# Out:
# defaultdict(dict,
#             {-20.0: {-20.0: {'means':                             0         1
#                2010-01-07 09:10:00  0.090292  0.086845
#                2010-01-07 09:20:00  0.092624  0.088530
#                2010-01-07 09:30:00  0.125896  0.149065
#                2010-01-07 09:40:00  0.112062  0.105159
#                2010-01-07 09:50:00  0.100621  0.100436
#                ...                       ...       ...
#                2010-01-22 06:00:00  0.109154  0.135994
#                2010-01-22 06:10:00  0.106419  0.139372
#                2010-01-22 06:20:00  0.108391  0.138333
#                2010-01-22 06:30:00  0.105185  0.138841
#                2010-01-22 06:40:00  0.100873  0.138910
#
#                [2146 rows x 2 columns],
#                'stds':                             0         1
#                2010-01-07 09:10:00  0.000127  0.000310
#                2010-01-07 09:20:00  0.000073  0.000068
# ...
